# %% [markdown]
# ## Q1. Write a program to calculate the electricity bill
# using only if statement? (accept number of unit from user)
# according to the following criteria:
#
# Unit Price
# First 100 units no charge
# Next 100 units Rs 5 per unit
# After 200 units Rs 10 per unit
# (For example, if input unit is 350 than total bill amount is Rs2000). Lets explain...
# For first 100 no charges
# Now you have 250 unit remaining
# 100-200 you need to pay – 100*5 = 500
# Now 200-100 you need to pay 150*10 = 1500
# Total = 500+1500 = 2000

# %%
unit=int(input("enter the unit"))

bill=0

if unit >200:
    bill=bill+(unit-200)*10
    unit=200

if unit >100:
    bill=bill+(unit-100)*5

print(f"the bill for {unit} will be {bill}")
# Out:
# enter the unit 350
# the bill for 200 will be 2000

# %% [markdown]
# ## Q2. Write a program to accept percentage from the user and display
# the grade according to the following criteria:
#
# Marks Grade
# > 90 A
# > 80 and <= 90 B
# >= 60 and <= 80 C
# below 60 D

# %%
per=int(input("enter your persentage"))

if per>90:
    print("Your grade is A")
elif per>80:
    print("Your grade is B")
elif per >=60:
    print("Your grade is C")
else:
    print("Your grade is D")
# Out:
# enter your persentage 60
# Your grade is C

# %%
## Q3. Accept the age of 4 people and display the youngest one?

# %%
per1=int(input("enter your age"))
per2=int(input("enter your age"))
per3=int(input("enter your age"))
per4=int(input("enter your age"))

listt=[per1,per2,per3,per4]
print(listt)

print("the youngest person is ",min(listt))
# Out:
# enter your age 22
# enter your age 33
# enter your age 40
# enter your age 20
# [22, 33, 40, 20]
# the youngest person is  20

# %% [markdown]
# ## Q4. A company decided to give bonus to employee according to following criteria:
#
# Time period of Service Bonus
#
# More than 10 years 10%
#
# >=6 and <=10 8%
#
# Less than 6 years 5%
#
# Ask user for their salary and years of service and print the
# net bonus amount?

# %%
period=int(input("enter the period of your servcie"))
salary=int(input("enter your salary"))

if period>10:
    result=salary+(salary*10)/100
    print(result)
elif period>=6:
    result=salary+(salary*8)/100
    print(result)
else:
    result=salary+(salary*5)/100
    print(result)
# Out:
# enter the period of your servcie 7
# enter your salary 10000
# 10800.0

# %% [markdown]
# ## Q6. Accept the marked price from the user and calculatethe Net amount as (Marked Price – Discount) to pay according to following criteria:
#
# Marked Price Discount
# >10000 20%
# >7000 and <=10000 15%
# <=7000 10%

# %%
marked_price=int(input("enter the marked_price "))

if marked_price>10000:
    result=marked_price-(marked_price*20)/100
    print(result)
elif marked_price >+7000:
    result=marked_price-(marked_price*15)/100
    print(result)
else:
    result=marked_price-(marked_price*10)/100
    print(result)
# Out:
# enter the marked_price  8000
# 6800.0

# %% [markdown]
# ## Q7. Accept the marks of English, Math and Science,Social Studies Subject and display the stream allotted according to following:
#
# All Subjects more than 80 marks — Science Stream
#
# English >80 and Math, Science above 50 — Commerce Stream
#
# English > 80 and social studies > 80 — Humanities

# %%
eng=int(input("entre the eng marks"))
math=int(input("entre the math ng marks"))
sci=int(input("entre the sci marks"))
sst=int(input("entre the sst marks"))

if eng>80 and math>80 and sci>80 and sst>80:
    print("u should take science sttream")
elif eng>80 and (math>50 and sci>50 and sst>50):
    print("u should take commerce stream")
elif eng>80 and sst>80:
    print("take humanities")
else:
    print("tumhara kuch nhi ho skta")
# Out:
# entre the eng marks 89
# entre the math ng marks 67
# entre the sci marks 89
# entre the sst marks 66
# u should take commerce stream

# %% [markdown]
# ##  Q8. Write a program to display "Hello" if a number entered by user is a multiple of five, otherwise print "Bye"?

# %%
n=int(input("enter the no."))

if n%5==0:
    print("heello")
else:
    print("bye")
# Out:
# enter the no. 5
# heello

# %% [markdown]
# ## Q9. Write a program to check whether the last digit of a number (entered by user) is divisible by 3 or not?

# %%
n=int(input("enter the no."))


if (n%10)%3==0:
    print("yes")
else:
    print("no")
# Out:
# enter the no. 9
# yes

# %%
num = int(input("Enter a number: "))

last_digit = num % 10

if last_digit % 3 == 0:
    print("Last digit is divisible by 3")
else:
    print("Last digit is NOT divisible by 3")
# Out:
# Enter a number:  27
# Last digit is NOT divisible by 3

# %% [markdown]
# ## Q10. Write a program to check whether a number entered is three-digit number or not?

# %%
n=int(input("enter the no."))

if n>100 and n<999:
    print("it is a 3 digit number")

else:
    print("no its not")
# Out:
# enter the no. 546
# it is a 3 digit number
